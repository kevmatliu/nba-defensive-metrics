# %%
import pandas as pd
from nba_api.stats.endpoints import leaguedashptstats

# %%
league_dash = leaguedashptstats.LeagueDashPtStats(player_or_team="Player")
league_dash_df = league_dash.get_data_frames()[0]

league_dash_df
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L  \
# 0      1630639      A.J. Lawson  1610612761               TOR  14   8   6
# 1      1631260         AJ Green  1610612749               MIL  62  37  25
# 2      1642358       AJ Johnson  1610612764               WAS  17   5  12
# 3       203932     Aaron Gordon  1610612743               DEN  43  28  15
# 4      1628988    Aaron Holiday  1610612745               HOU  52  32  20
# ..         ...              ...         ...               ...  ..  ..  ..
# 551     203897      Zach LaVine  1610612758               SAC  62  27  35
# 552    1630192       Zeke Nnaji  1610612743               DEN  51  34  17
# 553    1630533  Ziaire Williams  1610612751               BKN  54  19  35
# 554    1629627  Zion Williamson  1610612740               NOP  29  10  19
# 555    1642389      Zyon Pullin  1610612763               MEM   3   1   2
#
#         MIN  DIST_FEET  DIST_MILES  DIST_MILES_OFF  DIST_MILES_DEF  AVG_SPEED  \
# ...

# %%
league_dash_df["AVG_DIST_MILES_DEF"] = league_dash_df["DIST_MILES_DEF"] / league_dash_df["GP"]
league_dash_df["AVG_DIST_MILES_OFF"] = league_dash_df["DIST_MILES_OFF"] / league_dash_df["GP"]
league_dash_df["AVG_DIST_DEF_OFF_RATIO"] = league_dash_df["AVG_DIST_MILES_DEF"] / league_dash_df["AVG_DIST_MILES_OFF"]

league_dash_df["AVG_DIST_MILES_DEF_MIN"] = league_dash_df["DIST_MILES_DEF"] / league_dash_df["MIN"]
league_dash_df["AVG_DIST_MILES_OFF_MIN"] = league_dash_df["DIST_MILES_OFF"] / league_dash_df["MIN"]

league_dash_df["AVG_MIN"] = league_dash_df["MIN"] / league_dash_df["GP"]

league_dash_df
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID TEAM_ABBREVIATION  GP   W   L  \
# 0      1630639      A.J. Lawson  1610612761               TOR  14   8   6
# 1      1631260         AJ Green  1610612749               MIL  62  37  25
# 2      1642358       AJ Johnson  1610612764               WAS  17   5  12
# 3       203932     Aaron Gordon  1610612743               DEN  43  28  15
# 4      1628988    Aaron Holiday  1610612745               HOU  52  32  20
# ..         ...              ...         ...               ...  ..  ..  ..
# 551     203897      Zach LaVine  1610612758               SAC  62  27  35
# 552    1630192       Zeke Nnaji  1610612743               DEN  51  34  17
# 553    1630533  Ziaire Williams  1610612751               BKN  54  19  35
# 554    1629627  Zion Williamson  1610612740               NOP  29  10  19
# 555    1642389      Zyon Pullin  1610612763               MEM   3   1   2
#
#         MIN  DIST_FEET  DIST_MILES  ...  DIST_MILES_DEF  AVG_SPEED  \
# ...

# %%
league_dash_df.to_csv("data/speed-dist.csv")
